# %% [markdown]
# # Week 0 · Python / Colab Foundations
#
# 변수·함수·반복문을 실행하고 NumPy 배열의 shape를 읽습니다.
#
# [강의로 돌아가기](https://ml-fundamentals-karpnet.vercel.app/week/0)
#
# **사용법**: 파일 → Drive에 사본 저장 → 위에서 아래로 실행하세요. 런타임을 다시 시작했다면 설정 셀부터 다시 실행합니다. CPU 기준의 짧은 실습이며 데이터 다운로드가 없습니다. 실행 결과는 사이트에 자동 저장되지 않습니다.

# %% [markdown]
# ## 1. 실행 준비
#
# Colab 기본 Python 런타임의 NumPy·Matplotlib를 사용합니다. import 오류가 나면 새 기본 런타임으로 연결하세요.

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
print('Python:', sys.version.split()[0], '| NumPy:', np.__version__)

# %% [markdown]
# ## 2. 실행 전 예상
#
# predict(3, 2)는 무엇을 반환할까요? X의 행과 열은 각각 무엇을 의미할까요?
#
# 아래 칸에 예상과 이유를 먼저 적으세요.

# %% [markdown]
# **내 예상:**
#
# (여기에 작성)

# %% [markdown]
# ## 3. 실행하고 관찰하기
#
# 아래 parameter를 확인하고 두 코드 셀을 순서대로 실행하세요.

# %%
weight = 2.0  # Apply: 3.0으로 바꿔 보세요.

# %%
def predict(x, w):
    return w * x

X = np.array([[1., 2.], [3., 4.], [5., 6.]])
print('X shape:', X.shape, '| samples:', X.shape[0], '| features:', X.shape[1])
for x in [1, 2, 3]:
    print('input:', x, 'prediction:', predict(x, weight))
print('첫 번째 sample:', X[0])
print('두 번째 feature:', X[:, 1])
assert X.shape == (3, 2)

# %% [markdown]
# ## 4. Apply · 한 가지씩 바꾸기
#
# weight를 바꾸고 아래 셀을 다시 실행하세요. X에 행 하나를 추가한 뒤 shape와 첫 번째 sample을 확인하세요.
#
# parameter를 바꿀 때는 parameter 셀과 아래 실행 셀을 모두 다시 실행하세요.

# %% [markdown]
# | 바꾼 값 | 실행 전 예상 | 실제 결과 | 설명 |
# |---|---|---|---|
# | 기본값 | | | |
# | 변경 1 | | | |
# | 변경 2 | | | |

# %% [markdown]
# ## 5. Explore · 선택 확장
#
# Python list의 * 2와 NumPy array의 * 2는 같은 연산일까요? 각각 실행해 차이를 설명하세요.

# %%
# 선택 확장 코드를 여기에 작성하세요.

# %% [markdown]
# ## 6. 내 말로 설명하기
#
# - 예상과 결과가 달랐던 점은?
# - 이번 실습을 한 문장으로 설명하면?
# - 아직 설명하기 어려운 부분은?
#
# 답을 자신의 Drive 사본에 남긴 뒤 [사이트로 돌아가 학습 기록을 체크](https://ml-fundamentals-karpnet.vercel.app/week/0)하세요. 노트북 실행만으로 주차 잠금이나 완료 기록이 자동 변경되지는 않습니다.
